# %%
print("Selam ISTKA YZ Son Ders :DDD ")
# Out:
# Selam ISTKA YZ Son Ders :DDD

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/YAPAYZEKA')
# !pwd
# Out:
# /content/drive/My Drive/YAPAYZEKA

# %%
import os
import pandas as pd

VeriSetiYolu = '/content/drive/My Drive/veriseti'

csv_dosyalari = [dosya for dosya in os.listdir(VeriSetiYolu) if dosya.endswith('.csv')]

csv_dosya_sayisi = len(csv_dosyalari)
print("VeriSetiYolu dosyası içerisinde", csv_dosya_sayisi, "tane *.csv uzantılı dosyası bulunmaktadır.")

print("Bulunan CSV Dosyaları:")
for dosya in csv_dosyalari:
    print(dosya)
# Out:
# VeriSetiYolu dosyası içerisinde 1 tane *.csv uzantılı dosyası bulunmaktadır.
# Bulunan CSV Dosyaları:
# ilcesuveriseti.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

dosya_yolu = '/content/drive/My Drive/veriseti/ilcesuveriseti.csv'
csv_dosya = pd.read_csv(dosya_yolu)

print(csv_dosya)
# Out:
#    ID;ILCELER;2015;2016;2017;2018;2019;2020;2021;2022
# 0   1;ADALAR;1.432.494;1.472.276;1.366.581;1.399.1...
# 1   2;ARNAVUTKOY;8.002.123;9.178.953;10.176.132;11...
# 2   3;ATASEHIR;18.597.049;19.974.097;21.205.911;21...
# 3   4;AVCILAR;16.220.476;17.052.253;17.558.403;18....
# 4   5;BUYUKCEKMECE;9.915.435;10.788.924;11.172.787...
# 5   6;BAHCELIEVLER;23.610.609;24.320.533;24.868.59...
# 6   7;BAKIRKOY;11.510.117;11.793.169;12.509.301;15...
# 7   8;BAYRAMPASA;11.545.682;11.914.393;12.516.185;...
# 8   9;BAGCILAR;26.691.720;28.182.511;29.362.186;31...
# 9   10;BASAKSEHIR;16.174.934;18.100.255;19.576.095...
# 10  11;BEYKOZ;10.254.740;10.891.434;11.331.655;12....
# 11  12;BEYLIKDUZU;12.346.365;13.630.387;14.948.006...
# 12  13;BEYOGLU;11.167.382;11.311.755;11.420.559;12...
# 13  14;BESIKTAS;11.976.186;12.385.216;12.609.953;1...
# 14  15;ESENLER;15.854.265;16.584.976;17.162.651;17...
# 15  16;ESENYURT;27.933.397;32.799.007;36.083.030;3...
# 16  17;EYUPSULTAN;17.116.911;17.901.848;18.222.331...
# 17  18;FATIH;22.358.121;21.781.211;21.983.686;23.8...
# 18  19;GOP;17.730.853;18.637.751;18.940.716;19.614...
# 19  20;GUNGOREN;18.994.573;12.600.044;12.769.886;1...
# 20  21;KUCUKCEKMECE;29.188.561;31.086.665;31.994.3...
# 21  22;KADIKOY;23.910.542;24.310.256;24.797.597;26...
# 22  23;KARTAL;19.155.143;20.007.459;20.375.603;21....
# 23  24;KAGITHANE;18.207.418;19.030.632;19.286.724;...
# 24  25;MALTEPE;21.906.064;22.794.286;22.703.875;24...
# 25  26;PENDIK;26.499.977;28.474.258;29.743.117;31....
# 26  27;SANCAKTEPE;12.313.398;14.090.151;15.239.008...
# 27  28;SARIYER;17.555.072;18.711.570;19.427.187;20...
# 28  29;SULTANBEYLI;9.599.250;10.224.559;10.814.861...
# 29  30;SALTANGAZI;17.142.236;18.219.393;19.163.693...
# 30  31;SILIVRI;7.620.350;8.227.604;8.452.805;8.941...
# 31  32;TUZLA;11.546.080;12.690.324;13.625.147;14.9...
# 32  33;ZEYTINBURNU;12.576.945;13.068.037;13.469.51...
# 33  34;CATALCA;2.931.018;3.222.450;3.311.210;3.665...
# 34  35;CEKMEKOY;8.951.936;9.705.483;10.205.702;10....
# 35  36;UMRANIYE;28.085.173;30.065.065;31.061.816;3...
# 36  37;USKUDAR;25.142.059;26.110.542;26.353.986;27...
# 37  38;SILE;1.835.302;2.098.928;2.196.246;2.522.41...
# 38  39;SISLI;15.717.630;15.948.709;16.076.563;17.0...

# %%
# Veri setinin yolunun gösterimi ve yüklemesi
VeriSetiYolu = '/content/drive/My Drive/veriseti/ilcesuveriseti.csv'
data = pd.read_csv(VeriSetiYolu, delimiter=';')

# ; verilerini temizleyip , verisini dönüştürme işlemidir.
for i in data.columns[2:]:
    data[i] = data[i].str.replace('.', '').astype(int)

print(data.head())
# Out:
#    ID       ILCELER      2015      2016      2017      2018      2019  \
# 0   1        ADALAR   1432494   1472276   1366581   1399182   1371291
# 1   2    ARNAVUTKOY   8002123   9178953  10176132  11404878  13818204
# 2   3      ATASEHIR  18597049  19974097  21205911  21496185  22428468
# 3   4       AVCILAR  16220476  17052253  17558403  18312736  19485453
# 4   5  BUYUKCEKMECE   9915435  10788924  11172787  12222470  13606571
#
#        2020      2021      2022
# 0   1513070   1435991   1543403
# 1  15570466  17102127  18891299
# 2  23737630  24281319  24377611
# 3  20824893  20690506  21556002
# 4  16015731  16167480  17412198

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

data = pd.read_csv(VeriSetiYolu, delimiter=';')

for i in data.columns[2:]:
    data[i] = data[i].str.replace('.', '').astype(int)

ilceler = ["AVCILAR", "BEYLIKDUZU", "BUYUKCEKMECE", "KUCUKCEKMECE", "SILIVRI", "ESENYURT"]
filtre = data[data['ILCELER'].isin(ilceler)]

plt.figure(figsize=(15, 8))

for ilce in ilceler:
    ilce_data = filtre[filtre['ILCELER'] == ilce]
    plt.plot(data.columns[2:], ilce_data.iloc[0, 2:], label=ilce)

plt.xlabel('Yıllar')
plt.ylabel('Su Tüketimi (m3)')
plt.title('Belirli İlçelerin Yıllara Göre Su Tüketim Miktarları')

ax = plt.gca()
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{int(x):,}'))

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

data = pd.read_csv(VeriSetiYolu, delimiter=';')

for i in data.columns[2:]:
    data[i] = data[i].str.replace('.', '').astype(int)

ilce_bilgileri = ["AVCILAR", "BEYLIKDUZU", "BUYUKCEKMECE", "KUCUKCEKMECE", "SILIVRI", "ESENYURT"]
filtre = data[data['ILCELER'].isin(ilce_bilgileri)]

fig = go.Figure()

for ilce in ilce_bilgileri:
    ilce_data = filtre[filtre['ILCELER'] == ilce]
    fig.add_trace(go.Scatter(
         x=data.columns[2:],
         y=ilce_data.iloc[0, 2:],
         mode='lines+markers',
         line=dict(width=3),
         name=ilce
        ))

fig.update_layout(
        title='AVCILAR, BEYLIKDUZU, BUYUKCEKMECE, KUCUKCEKMECE, SILIVRI, ESENYURT İlçelerin Yıllara Göre Su Tüketim Miktarları',
        xaxis_title='Yıllar',
        yaxis_title='Su Tüketimi (m3)',
        yaxis=dict(tickformat=','),
        template='plotly_white'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a7061fa2-86a7-4708-99e7-4f92b5430cae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7061fa2-86a7-4708-99e7-4f92b5430cae")) {                    Plotly.newPlot(                        "a7061fa2-86a7-4708-99e7-4f92b5430cae",                        [{"line":{"width":3},"mode":"lines+markers","name":"AVCILAR","x":["2015","2016","2017","2018","2019","2020","2021","2022"],"y":[16220476,17052253,17558403,18312736,19485453,20824893,20690506,21556002],"type":"scatter"},{"line":{"width":3},"mode":"lines+markers","name":"BEYLIKDUZU","x":["2015","2016","2017","2018","2019","2020","2021","2022"],"y":[12346365,13630387,14948006,16738110,17387725,20325425,20415406,22961265],"type":"scatter"},{"line":{"width":3},"mode":"lines+markers","name":"BUYUKCEKMECE","x":["2015","2016","2017","2018","2019","2020","2021","2022"],"y":[9915435,10788924,11172787,12222470,13606571,16015731,16167480,17412198],"type":"scatter"},{"line":{"width":3},"mode":"lines+markers","name":"KUCUKCEKMECE","x":["2015","2016","2017","2018","2019","2020","2021","2022"],"y":[29188561,31086665,31994320,33889979,35731905,38012294,38030116,38832413],"type":"scatter"},{"line":{"width":3},"mode":"lines+markers","name":"SILIVRI","x":["2015","2016","2017","2018","2019","2020","2021","2022"],"y":[7620350,8227604,8452805,8941729,10056059,11744060,12232563,13216660],"type":"scatter"},{"line":{"width":3},"mode":"lines+markers","name":"ESENYURT","x":["2015","2016","2017","2018","2019","2020","2021","2022"],"y":[27933397,32799007,36083030,39205682,43576187,59865610,48988082,52836878],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179 ...

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.2)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

data = pd.read_csv(VeriSetiYolu, delimiter=';')

for col in data.columns[2:]:
    data[col] = data[col].str.replace('.', '').astype(int)

selected_ilces = ["AVCILAR", "BEYLIKDUZU", "BUYUKCEKMECE", "KUCUKCEKMECE", "SILIVRI", "ESENYURT"]
filtered_data = data[data['ILCELER'].isin(selected_ilces)]

ilce = 'AVCILAR'
ilce_data = filtered_data[filtered_data['ILCELER'] == ilce].iloc[0, 2:].values.reshape(-1, 1)

years = data.columns[2:].astype(int)

scaler = MinMaxScaler(feature_range=(0, 1))
ilce_data_scaled = scaler.fit_transform(ilce_data)

def create_dataset(dataset, tahmin_adimi=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - tahmin_adimi):
        a = dataset[i:(i + tahmin_adimi), 0]
        dataX.append(a)
        dataY.append(dataset[i + tahmin_adimi, 0])
    return np.array(dataX), np.array(dataY)

tahmin_adimi = 4
trainX, trainY = create_dataset(ilce_data_scaled, tahmin_adimi)

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(tahmin_adimi, 1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2, validation_split=0.2)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Epoch 1/100
# 3/3 - 4s - 1s/step - loss: 0.5888 - val_loss: 0.9040
# Epoch 2/100
# 3/3 - 0s - 20ms/step - loss: 0.5335 - val_loss: 0.8058
# Epoch 3/100
# 3/3 - 0s - 19ms/step - loss: 0.4806 - val_loss: 0.7007
# Epoch 4/100
# 3/3 - 0s - 20ms/step - loss: 0.4192 - val_loss: 0.5863
# Epoch 5/100
# 3/3 - 0s - 21ms/step - loss: 0.3484 - val_loss: 0.4610
# Epoch 6/100
# 3/3 - 0s - 46ms/step - loss: 0.2770 - val_loss: 0.3231
# Epoch 7/100
# 3/3 - 0s - 20ms/step - loss: 0.1865 - val_loss: 0.1852
# Epoch 8/100
# 3/3 - 0s - 19ms/step - loss: 0.1087 - val_loss: 0.0627
# Epoch 9/100
# 3/3 - 0s - 20ms/step - loss: 0.0375 - val_loss: 6.7995e-04
# Epoch 10/100
# 3/3 - 0s - 18ms/step - loss: 0.0016 - val_loss: 0.0459
# Epoch 11/100
# 3/3 - 0s - 19ms/step - loss: 0.0315 - val_loss: 0.1382
# Epoch 12/100
# 3/3 - 0s - 23ms/step - loss: 0.0440 - val_loss: 0.0975
# Epoch 13/100
# 3/3 - 0s - 19ms/step - loss: 0.0269 - val_loss: 0.0400
# Epoch 14/100
# 3/3 - 0s - 20ms/step - loss: 0.0113 - val_loss: 0.0070
# Epoch 15/100
# 3/3 - 0s - 17ms/step - loss: 0.0048 - val_loss: 6.1017e-05
# Epoch 16/100
# 3/3 - 0s - 18ms/step - loss: 0.0078 - val_loss: 0.0010
# Epoch 17/100
# 3/3 - 0s - 22ms/step - loss: 0.0102 - val_loss: 0.0016
# Epoch 18/100
# 3/3 - 0s - 24ms/step - loss: 0.0099 - val_loss: 5.5398e-04
# Epoch 19/100
# 3/3 - 0s - 42ms/step - loss: 0.0072 - val_loss: 1.2147e-05
# Epoch 20/100
# 3/3 - 0s - 18ms/step - loss: 0.0050 - val_loss: 0.0015
# Epoch 21/100
# 3/3 - 0s - 21ms/step - loss: 0.0040 - val_loss: 0.0049
# Epoch 22/100
# 3/3 - 0s - 22ms/step - loss: 0.0049 - val_loss: 0.0090
# Epoch 23/100
# 3/3 - 0s - 19ms/step - loss: 0.0069 - val_loss: 0.0125
# Epoch 24/100
# 3/3 - 0s - 19ms/step - loss: 0.0066 - val_loss: 0.0083
# Epoch 25/100
# 3/3 - 0s - 19ms/step - loss: 0.0052 - val_loss: 0.0059
# Epoch 26/100
# 3/3 - 0s - 20ms/step - loss: 0.0059 - val_loss: 0.0018
# Epoch 27/100
# 3/3 - 0s - 23ms/step - loss: 0.0054 - val_loss: 4.9267e-04
# Epoch 28/100
# 3/3 - 0s - 19ms/step - loss: 0.0052 - val_loss: 5.0093e-04
# Epoch 29/100
# 3/3 - 0s - 20ms/step - loss: 0.0053 - val_loss: 0.0011
# Epoch 30/100
# 3/3 - 0s - 18ms/step - loss: 0.0049 - val_loss: 0.0018
# Epoch 31/100
# 3/3 - 0s - 23ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 32/100
# 3/3 - 0s - 43ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 33/100
# 3/3 - 0s - 19ms/step - loss: 0.0048 - val_loss: 0.0028
# Epoch 34/100
# 3/3 - 0s - 20ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 35/100
# 3/3 - 0s - 19ms/step - loss: 0.0048 - val_loss: 0.0029
# Epoch 36/100
# 3/3 - 0s - 18ms/step - loss: 0.0053 - val_loss: 0.0013
# Epoch 37/100
# 3/3 - 0s - 19ms/step - loss: 0.0048 - val_loss: 9.2224e-04
# Epoch 38/100
# 3/3 - 0s - 45ms/step - loss: 0.0049 - val_loss: 6.5739e-04
# Epoch 39/100
# 3/3 - 0s - 20ms/step - loss: 0.0048 - val_loss: 7.3778e-04
# Epoch 40/100
# 3/3 - 0s - 19ms/step - loss: 0.0051 - val_loss: 0.0019
# Epoch 41/100
# 3/3 - 0s - 23ms/step - loss: 0.0047 - val_loss: 0.0022
# Epoch 42/100
# 3/3 - 0s - 22ms/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 43/100
# 3/3 - 0s - 44ms/step - loss: 0.0049 - val_loss: 0.0020
# Epoch 44/100
# 3/3 - 0s - 45ms/step - loss: 0.0047 - val_loss: 0.0018
# Epoch 45/100
# 3/3 - 0s - 20ms/step - loss: 0.0053 - val_loss: 4.9414e-04
# Epoch 46/100
# 3/3 - 0s - 19ms/step - loss: 0.0048 - val_loss: 4.7245e-04
# Epoch 47/100
# 3/3 - 0s - 20ms/step - loss: 0.0050 - val_loss: 9.9781e-04
# Epoch 48/100
# 3/3 - 0s - 19ms/step - loss: 0.0048 - val_loss: 0.0014
# Epoch 49/100
# 3/3 - 0s - 19ms/step - loss: 0.0047 - val_loss: 0.0012
# Epoch 50/100
# 3/3 - 0s - 46ms/step - loss: 0.0047 - val_loss: 8.8440e-04
# Epoch 51/100
# 3/3 - 0s - 19ms/step - loss: 0.0050 - val_loss: 3.9666e-04
# Epoch 52/100
# 3/3 - 0s - 18ms/step - loss: 0.0048 - val_loss: 3.4394e-04
# Epoch 53/100
# 3/3 - 0s - 30ms/step - loss: 0.0052 - val_loss: 0.0013
# Epoch 54/100
# 3/3 - 0s - 18ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 55/100
# 3/3 - 0s - 19ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 56/100
# 3/3 - 0s - 21ms/step - loss: 0.0049 - val_loss: 0.0018
# Epoch 57/100
# 3/3 - 0s - 44ms/step - loss: 0.0047 - val_loss: 0.0010
# Epoch 58/100
# 3/3 - 0s - 18ms/step - loss: 0.0046 - val_loss: 7.8324e-04
# Epoch 59/100
# 3/3 - 0s - 17ms/step - loss: 0.0046 - val_loss: 5.6170e-04
# Epoch 60/100
# 3/3 - 0s - 20ms/step - loss: 0.0046 - val_loss: 5.0192e-04
# Epoch 61/100
# 3/3 - 0s - 20ms/step - loss: 0.0046 - val_loss: 4.3036e-04
# Epoch 62/100
# 3/3 - 0s - 19ms/step - loss: 0.0047 - val_loss: 4.8648e-04
# Epoch 63/100
# 3/3 - 0s - 18ms/step - loss: 0.0047 - val_loss: 2.2714e-04
# Epoch 64/100
# 3/3 - 0s - 20ms/step - loss: 0.0049 - val_loss: 5.0327e-04
# Epoch 65/100
# 3/3 - 0s - 19ms/step - loss: 0.0048 - val_loss: 6.9608e-04
# Epoch 66/100
# 3/3 - 0s - 21ms/step - loss: 0.0047 - val_loss: 7.5008e-04
# Epoch 67/100
# 3/3 - 0s - 19ms/step - loss: 0.0050 - val_loss: 1.4987e-04
# Epoch 68/100
# 3/3 - 0s - 22ms/step - loss: 0.0050 - val_loss: 2.6688e-05
# Epoch 69/100
# 3/3 - 0s - 18ms/step - loss: 0.0051 - val_loss: 4.9336e-04
# Epoch 70/100
# 3/3 - 0s - 18ms/step - loss: 0.0047 - val_loss: 3.6713e-04
# Epoch 71/100
# 3/3 - 0s - 25ms/step - loss: 0.0051 - val_loss: 0.0012
# Epoch 72/100
# 3/3 - 0s - 22ms/step - loss: 0.0047 - val_loss: 9.4994e-04
# Epoch 73/100
# 3/3 - 0s - 20ms/step - loss: 0.0046 - val_loss: 7.5001e-04
# Epoch 74/100
# 3/3 - 0s - 18ms/step - loss: 0.0047 - val_loss: 3.9795e-04
# Epoch 75/100
# 3/3 - 0s - 18ms/step - loss: 0.0047 - val_loss: 5.1509e-04
# Epoch 76/100
# 3/3 - 0s - 20ms/step - loss: 0.0047 - val_loss: 5.8342e-04
# Epoch 77/100
# 3/3 - 0s - 19ms/step - loss: 0.0046 - val_loss: 5.0807e-04
# Epoch 78/100
# 3/3 - 0s - 20ms/step - loss: 0.0046 - val_loss: 3.7259e-04
# Epoch 79/100
# 3/3 - 0s - 18ms/step - loss: 0.0046 - val_loss: 9.9243e-05
# Epoch 80/100
# 3/3 - 0s - 20ms/step - loss: 0.0048 - val_loss: 3.7096e-05
# Epoch 81/100
# 3/3 - 0s - 20ms/step - loss: 0.0049 - val_loss: 2.6781e-04
# Epoch 82/100
# 3/3 - 0s - 19ms/step - loss: 0.0046 - val_loss: 3.5471e-04
# Epoch 83/100
# 3/3 - 0s - 19ms/step - loss: 0.0048 - val_loss: 6.9061e-04
# Epoch 84/100
# 3/3 - 0s - 20ms/step - loss: 0.0048 - val_loss: 8.3044e-04
# Epoch 85/100
# 3/3 - 0s - 46ms/step - loss: 0.0052 - val_loss: 5.3759e-05
# Epoch 86/100
# 3/3 - 0s - 44ms/step - loss: 0.0047 - val_loss: 3.0665e-05
# Epoch 87/100
# 3/3 - 0s - 20ms/step - loss: 0.0048 - val_loss: 5.6946e-06
# Epoch 88/100
# 3/3 - 0s - 19ms/step - loss: 0.0051 - val_loss: 4.8315e-04
# Epoch 89/100
# 3/3 - 0s - 18ms/step - loss: 0.0050 - val_loss: 0.0011
# Epoch 90/100
# 3/3 - 0s - 17ms/step - loss: 0.0051 - val_loss: 2.7831e-04
# Epoch 91/100
# 3/3 - 0s - 18ms/step - loss: 0.0046 - val_loss: 2.5385e-04
# Epoch 92/100
# 3/3 - 0s - 19ms/step - loss: 0.0046 - val_loss: 2.0532e-04
# Epoch 93/100
# 3/3 - 0s - 20ms/step - loss: 0.0048 - val_loss: 4.8235e-04
# Epoch 94/100
# 3/3 - 0s - 18ms/step - loss: 0.0047 - val_loss: 5.6288e-04
# Epoch 95/100
# 3/3 - 0s - 18ms/step - loss: 0.0047 - val_loss: 1.5793e-04
# Epoch 96/100
# 3/3 - 0s - 17ms/step - loss: 0.0046 - val_loss: 1.9025e-04
# Epoch 97/100
# 3/3 - 0s - 18ms/step - loss: 0.0046 - val_loss: 7.5914e-05
# Epoch 98/100
# 3/3 - 0s - 21ms/step - loss: 0.0047 - val_loss: 5.0121e-05
# Epoch 99/100
# 3/3 - 0s - 47ms/step - loss: 0.0049 - val_loss: 3.3029e-04
# Epoch 100/100
# 3/3 - 0s - 23ms/step - loss: 0.0049 - val_loss: 4.0120e-05

# %%
trainPredict = model.predict(trainX)
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
test_data = ilce_data_scaled[-tahmin_adimi:]
test_data = np.reshape(test_data, (1, tahmin_adimi, 1))
test_predict = model.predict(test_data)
test_predict = scaler.inverse_transform(test_predict)
test_y = ilce_data[-1:]
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.title('Model Eğitim ve Doğrulama Kaybı')
plt.xlabel('Epoch')
plt.ylabel('Kayıp')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 776ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
Modelin_kayip_degeri = [loss * 100 for loss in history.history['loss']]
for epoch, loss in enumerate(Modelin_kayip_degeri, 1):
    print(f"Eğitim Adımı {epoch}: Kayıp Oranı = {loss:.2f}%")
Kayip_hesabi = np.mean(Modelin_kayip_degeri)
print("Eğitim Modelinin Toplam Kayıp Oranı (Yüzdelik): ", Kayip_hesabi)
print("Eğitim Modelinin Başarı Oranı (Yüzdelik): ", 100-Kayip_hesabi)
# Out:
# Eğitim Adımı 1: Kayıp Oranı = 58.88%
# Eğitim Adımı 2: Kayıp Oranı = 53.35%
# Eğitim Adımı 3: Kayıp Oranı = 48.06%
# Eğitim Adımı 4: Kayıp Oranı = 41.92%
# Eğitim Adımı 5: Kayıp Oranı = 34.84%
# Eğitim Adımı 6: Kayıp Oranı = 27.70%
# Eğitim Adımı 7: Kayıp Oranı = 18.65%
# Eğitim Adımı 8: Kayıp Oranı = 10.87%
# Eğitim Adımı 9: Kayıp Oranı = 3.75%
# Eğitim Adımı 10: Kayıp Oranı = 0.16%
# Eğitim Adımı 11: Kayıp Oranı = 3.15%
# Eğitim Adımı 12: Kayıp Oranı = 4.40%
# Eğitim Adımı 13: Kayıp Oranı = 2.69%
# Eğitim Adımı 14: Kayıp Oranı = 1.13%
# Eğitim Adımı 15: Kayıp Oranı = 0.48%
# Eğitim Adımı 16: Kayıp Oranı = 0.78%
# Eğitim Adımı 17: Kayıp Oranı = 1.02%
# Eğitim Adımı 18: Kayıp Oranı = 0.99%
# Eğitim Adımı 19: Kayıp Oranı = 0.72%
# Eğitim Adımı 20: Kayıp Oranı = 0.50%
# Eğitim Adımı 21: Kayıp Oranı = 0.40%
# Eğitim Adımı 22: Kayıp Oranı = 0.49%
# Eğitim Adımı 23: Kayıp Oranı = 0.69%
# Eğitim Adımı 24: Kayıp Oranı = 0.66%
# Eğitim Adımı 25: Kayıp Oranı = 0.52%
# Eğitim Adımı 26: Kayıp Oranı = 0.59%
# Eğitim Adımı 27: Kayıp Oranı = 0.54%
# Eğitim Adımı 28: Kayıp Oranı = 0.52%
# Eğitim Adımı 29: Kayıp Oranı = 0.53%
# Eğitim Adımı 30: Kayıp Oranı = 0.49%
# Eğitim Adımı 31: Kayıp Oranı = 0.48%
# Eğitim Adımı 32: Kayıp Oranı = 0.48%
# Eğitim Adımı 33: Kayıp Oranı = 0.48%
# Eğitim Adımı 34: Kayıp Oranı = 0.51%
# Eğitim Adımı 35: Kayıp Oranı = 0.48%
# Eğitim Adımı 36: Kayıp Oranı = 0.53%
# Eğitim Adımı 37: Kayıp Oranı = 0.48%
# Eğitim Adımı 38: Kayıp Oranı = 0.49%
# Eğitim Adımı 39: Kayıp Oranı = 0.48%
# Eğitim Adımı 40: Kayıp Oranı = 0.51%
# Eğitim Adımı 41: Kayıp Oranı = 0.47%
# Eğitim Adımı 42: Kayıp Oranı = 0.51%
# Eğitim Adımı 43: Kayıp Oranı = 0.49%
# Eğitim Adımı 44: Kayıp Oranı = 0.47%
# Eğitim Adımı 45: Kayıp Oranı = 0.53%
# Eğitim Adımı 46: Kayıp Oranı = 0.48%
# Eğitim Adımı 47: Kayıp Oranı = 0.50%
# Eğitim Adımı 48: Kayıp Oranı = 0.48%
# Eğitim Adımı 49: Kayıp Oranı = 0.47%
# Eğitim Adımı 50: Kayıp Oranı = 0.47%
# Eğitim Adımı 51: Kayıp Oranı = 0.50%
# Eğitim Adımı 52: Kayıp Oranı = 0.48%
# Eğitim Adımı 53: Kayıp Oranı = 0.52%
# Eğitim Adımı 54: Kayıp Oranı = 0.47%
# Eğitim Adımı 55: Kayıp Oranı = 0.47%
# Eğitim Adımı 56: Kayıp Oranı = 0.49%
# Eğitim Adımı 57: Kayıp Oranı = 0.47%
# Eğitim Adımı 58: Kayıp Oranı = 0.46%
# Eğitim Adımı 59: Kayıp Oranı = 0.46%
# Eğitim Adımı 60: Kayıp Oranı = 0.46%
# Eğitim Adımı 61: Kayıp Oranı = 0.46%
# Eğitim Adımı 62: Kayıp Oranı = 0.47%
# Eğitim Adımı 63: Kayıp Oranı = 0.47%
# Eğitim Adımı 64: Kayıp Oranı = 0.49%
# Eğitim Adımı 65: Kayıp Oranı = 0.48%
# Eğitim Adımı 66: Kayıp Oranı = 0.47%
# Eğitim Adımı 67: Kayıp Oranı = 0.50%
# Eğitim Adımı 68: Kayıp Oranı = 0.50%
# Eğitim Adımı 69: Kayıp Oranı = 0.51%
# Eğitim Adımı 70: Kayıp Oranı = 0.47%
# Eğitim Adımı 71: Kayıp Oranı = 0.51%
# Eğitim Adımı 72: Kayıp Oranı = 0.47%
# Eğitim Adımı 73: Kayıp Oranı = 0.46%
# Eğitim Adımı 74: Kayıp Oranı = 0.47%
# Eğitim Adımı 75: Kayıp Oranı = 0.47%
# Eğitim Adımı 76: Kayıp Oranı = 0.47%
# Eğitim Adımı 77: Kayıp Oranı = 0.46%
# Eğitim Adımı 78: Kayıp Oranı = 0.46%
# Eğitim Adımı 79: Kayıp Oranı = 0.46%
# Eğitim Adımı 80: Kayıp Oranı = 0.48%
# Eğitim Adımı 81: Kayıp Oranı = 0.49%
# Eğitim Adımı 82: Kayıp Oranı = 0.46%
# Eğitim Adımı 83: Kayıp Oranı = 0.48%
# Eğitim Adımı 84: Kayıp Oranı = 0.48%
# Eğitim Adımı 85: Kayıp Oranı = 0.52%
# Eğitim Adımı 86: Kayıp Oranı = 0.47%
# Eğitim Adımı 87: Kayıp Oranı = 0.48%
# Eğitim Adımı 88: Kayıp Oranı = 0.51%
# Eğitim Adımı 89: Kayıp Oranı = 0.50%
# Eğitim Adımı 90: Kayıp Oranı = 0.51%
# Eğitim Adımı 91: Kayıp Oranı = 0.46%
# Eğitim Adımı 92: Kayıp Oranı = 0.46%
# Eğitim Adımı 93: Kayıp Oranı = 0.48%
# Eğitim Adımı 94: Kayıp Oranı = 0.47%
# Eğitim Adımı 95: Kayıp Oranı = 0.47%
# Eğitim Adımı 96: Kayıp Oranı = 0.46%
# Eğitim Adımı 97: Kayıp Oranı = 0.46%
# Eğitim Adımı 98: Kayıp Oranı = 0.47%
# Eğitim Adımı 99: Kayıp Oranı = 0.49%
# Eğitim Adımı 100: Kayıp Oranı = 0.49%
# Eğitim Modelinin Toplam Kayıp Oranı (Yüzdelik):  3.5323481201194227
# Eğitim Modelinin Başarı Oranı (Yüzdelik):  96.46765187988058

# %%
import matplotlib.pyplot as plt
import numpy as np
Modelin_kayip_degeri = [loss * 100 for loss in history.history['loss']]
Basari_orani = [100 - loss for loss in Modelin_kayip_degeri]
epoch_sayisi = range(1, len(Basari_orani) + 1)
plt.figure(figsize=(10, 6))
plt.plot(epoch_sayisi, Basari_orani, linestyle='-', color='b')
plt.title("Eğitim Sürecinde Başarı Oranı")
plt.xlabel("Adım Sayısı")
plt.ylabel("Başarı Oranı (%)")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
Modelin_kayip_degeri = [loss * 100 for loss in history.history['loss']]
epoch_sayisi = range(1, len(Modelin_kayip_degeri) + 1)
plt.figure(figsize=(10, 6))
plt.plot(epoch_sayisi, Modelin_kayip_degeri, linestyle='-', color='r') # marker='o'
plt.title("Eğitim Sürecinde Hata Oranı")
plt.xlabel("Adım Sayısı")
plt.ylabel("Hata Oranı (%)")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
Modelin_kayip_degeri = [loss * 100 for loss in history.history['loss']]
Basari_orani = [100 - loss for loss in Modelin_kayip_degeri]
epoch_sayisi = range(1, len(Modelin_kayip_degeri) + 1)
plt.figure(figsize=(10, 6))
plt.plot(epoch_sayisi, Modelin_kayip_degeri, linestyle='-', color='r', label='Hata Oranı (%)')
plt.plot(epoch_sayisi, Basari_orani, linestyle='-', color='b', label='Başarı Oranı (%)')
plt.title("Eğitim Sürecinde Başarı ve Hata Oranı")
plt.xlabel("Adım Sayısı")
plt.ylabel("Oran (%)")
plt.legend()
plt.grid(True)
plt.show()

# %%
#Modelin tahmin performansını çizdirme
time_step = len(ilce_data) - len(trainY[0])
plt.figure(figsize=(12, 6))
plt.plot(years[time_step:time_step + len(trainY[0])], trainY[0], label='Gerçek Değerler', color='blue')
plt.plot(years[time_step:time_step + len(trainPredict)], trainPredict, label='Tahminler', color='red')
plt.title('Avcılar İlçesi için Gerçek Su Kullanım Değerleri ve Tahmin Edilen Değerlerin Görselleştirilmesi')
plt.xlabel('Yıl')
plt.ylabel('Su Tüketimi x (10^6) m^3')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
import numpy as np
farklar = np.array(trainY[0]) - np.array(trainPredict)
mutlak_farklar = np.abs(farklar)
yuzdelik_hatalar = (mutlak_farklar / np.array(trainY[0])) * 100
ortalama_yuzdelik_hata = np.mean(yuzdelik_hatalar)
#Sonuçları yazdırma
for year, gercek, tahmin, fark in zip(years[time_step:time_step + len(trainY[0])], trainY[0], trainPredict.flatten(), mutlak_farklar.flatten()):
    print("Yıl:", year ,"Gerçek: ", gercek, "Tahmin: ", tahmin, "Mutlak Fark: ", fark)
print("Ortalama Mutlak Hata: ", ortalama_yuzdelik_hata)
# Out:
# Yıl: 2019 Gerçek:  19485453.0 Tahmin:  19714280.0 Mutlak Fark:  228827.0
# Yıl: 2020 Gerçek:  20824893.0 Tahmin:  20288002.0 Mutlak Fark:  1110613.0
# Yıl: 2021 Gerçek:  20690506.0 Tahmin:  20892608.0 Mutlak Fark:  976226.0
# Yıl: 2022 Gerçek:  21556002.0 Tahmin:  21589798.0 Mutlak Fark:  1841722.0
# Ortalama Mutlak Hata:  4.054434485691308

# %%
Sistemin_toplam_hata_payi = abs(Kayip_hesabi - ortalama_yuzdelik_hata)
print("Geliştirilen Sistemin Yüzdelik oranıdaki hata payı=> %",Sistemin_toplam_hata_payi)
# Out:
# Geliştirilen Sistemin Yüzdelik oranıdaki hata payı=> % 0.5220863655718855
